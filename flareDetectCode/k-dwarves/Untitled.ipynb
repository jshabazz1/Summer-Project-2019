# %%
from IPython.display import Image

# %%
import eleanor
import numpy as np
import matplotlib.pyplot as plt
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.table import Table

# %%
flares = Table.read("/Users/jshabazz/flareDetectCode/textfiles/guenther_flares.csv",format='ascii')
ids = flares['tic_id'][0:5]
sector = flares['sector'][0:5]
print(sector[0])
# Out:
# 1

# %%
for this_id in ids:
    star = eleanor.Source(tic = this_id , sector = 1)
    print('Found TIC {0} (Gaia {1}), with TESS magnitude {2}, RA {3}, and Dec {4}'.format(star.tic, star.gaia, star.tess_mag, star.coords[0], star.coords[1]))
    data = eleanor.TargetData(star, height=15, width=15, bkg_size=31, do_psf=True, do_pca=True)
    plt.figure(figsize = (15,5))

    q = data.quality == 0

    #plt.plot(data.time[q], data.raw_flux[q]/np.nanmedian(data.raw_flux[q])+0.06, 'k')
    #plt.plot(data.time[q], data.corr_flux[q]/np.nanmedian(data.corr_flux[q]) + 0.03, 'r')
    plt.plot(data.time[q], data.pca_flux[q]/np.nanmedian(data.pca_flux[q]), 'g')
    #plt.plot(data.time[q], data.psf_flux[q]/np.nanmedian(data.psf_flux[q]) - 0.02, 'b')
    plt.ylabel('Normalized Flux')
    plt.xlabel('Time [BJD - 2457000]')
    plt.title('WASP-100')
# Out:
# INFO: Found cached file /Users/jshabazz/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-1-1-cal-0510-1132_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-1-1-cal-0510-1132_tess_v2_bkg.fits with expected size 78955200. [astroquery.query]
# INFO: Found cached file /Users/jshabazz/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-1-1-cal-0510-1132_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-1-1-cal-0510-1132_tess_v2_pc.fits with expected size 158022720. [astroquery.query]
# INFO: Found cached file /Users/jshabazz/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-1-1-cal-0510-1132_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-1-1_tess_v2_pm.txt with expected size 238653. [astroquery.query]
# Found TIC 114953216 (Gaia 6773453838597541760), with TESS magnitude 11.6672, RA 315.265916074587, and Dec -41.2425790263418
# /Users/jshabazz/anaconda3/lib/python3.7/site-packages/astropy/wcs/wcs.py:682: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58324.817595 from DATE-OBS.
# Set DATE-BEG to '2018-07-25T19:38:29.391' from MJD-BEG'.
#   FITSFixedWarning)
# /Users/jshabazz/anaconda3/lib/python3.7/site-packages/photutils/aperture/core.py:130: AstropyUserWarning: The "exact" method is not yet implemented for rectangular apertures -- using "subpixel" method with "subpixels=32"
#   'with "subpixels=32"', AstropyUserWarning)
# 100%|██████████| 1282/1282 [00:15<00:00, 81.98it/s]
# INFO: Found cached file /Users/jshabazz/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-1-1-cal-0510-1078_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-1-1-cal-0510-1078_tess_v2_bkg.fits with expected size 78955200. [astroquery.query]
# INFO: Found cached file /Users/jshabazz/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-1-1-cal-0510-1078_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-1-1-cal-0510-1078_tess_v2_pc.fits with expected size 158022720. [astroquery.query]
# Found TIC 114985772 (Gaia 6773423224070637952), with TESS magnitude 11.1087, RA 315.228935617079, and Dec -41.5288841426642
# /Users/jshabazz/anaconda3/lib/python3.7/site-packages/astropy/wcs/wcs.py:682: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58324.817595 from DATE-OBS.
# Set DATE-BEG to '2018-07-25T19:38:29.391' from MJD-BEG'.
#   FITSFixedWarning)
# /Users/jshabazz/anaconda3/lib/python3.7/site-packages/photutils/aperture/core.py:130: AstropyUserWarning: The "exact" method is not yet implemented for rectangular apertures -- using "subpixel" method with "subpixels=32"
#   'with "subpixels=32"', AstropyUserWarning)
# 100%|██████████| 1282/1282 [00:14<00:00, 88.75it/s]
# INFO: Found cached file /Users/jshabazz/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-1-1-cal-0706-1780_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-1-1-cal-0706-1780_tess_v2_bkg.fits with expected size 78955200. [astroquery.query]
# INFO: Found cached file /Users/jshabazz/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-1-1-cal-0706-1780_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-1-1-cal-0706-1780_tess_v2_pc.fits with expected size 158022720. [astroquery.query]
# Found TIC 115015715 (Gaia 6775274934799202688), with TESS magnitude 10.7157, RA 315.691720008771, and Dec -37.364209020659
# /Users/jshabazz/anaconda3/lib/python3.7/site-packages/astropy/wcs/wcs.py:682: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58324.817595 from DATE-OBS.
# Set DATE-BEG to '2018-07-25T19:38:29.391' from MJD-BEG'.
#   FITSFixedWarning)
# /Users/jshabazz/anaconda3/lib/python3.7/site-packages/photutils/aperture/core.py:130: AstropyUserWarning: The "exact" method is not yet implemented for rectangular apertures -- using "subpixel" method with "subpixels=32"
#   'with "subpixels=32"', AstropyUserWarning)
# 100%|██████████| 1282/1282 [00:14<00:00, 89.47it/s]
# INFO: Found cached file /Users/jshabazz/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-1-1-cal-0902-1294_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-1-1-cal-0902-1294_tess_v2_bkg.fits with expected size 78955200. [astroquery.query]
# INFO: Found cached file /Users/jshabazz/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-1-1-cal-0902-1294_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-1-1-cal-0902-1294_tess_v2_pc.fits with expected size 158022720. [astroquery.query]
# Found TIC 115190256 (Gaia 6581893555552432128), with TESS magnitude 12.5616, RA 317.467204472384, and Dec -39.8378708301111
# /Users/jshabazz/anaconda3/lib/python3.7/site-packages/astropy/wcs/wcs.py:682: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58324.817595 from DATE-OBS.
# Set DATE-BEG to '2018-07-25T19:38:29.391' from MJD-BEG'.
#   FITSFixedWarning)
# /Users/jshabazz/anaconda3/lib/python3.7/site-packages/photutils/aperture/core.py:130: AstropyUserWarning: The "exact" method is not yet implemented for rectangular apertures -- using "subpixel" method with "subpixels=32"
#   'with "subpixels=32"', AstropyUserWarning)
# 100%|██████████| 1282/1282 [00:16<00:00, 76.62it/s]
# INFO: Found cached file /Users/jshabazz/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-2-3-cal-1098-0700_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-2-3-cal-1098-0700_tess_v2_bkg.fits with expected size 78955200. [astroquery.query]
#  [Done]
# WARNING: Found cached file /Users/jshabazz/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-2-3-cal-1098-0700_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-2-3-cal-1098-0700_tess_v2_pc.fits with size 1441792 that is different from expected size 158022720 [astroquery.query]
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:HLSP/eleanor/postcards/s0001/2-3/hlsp_eleanor_tess_ffi_postcard-s0001-2-3_tess_v2_pm.txt to /Users/jshabazz/.eleanor/mastDownload/HLSP/hlsp_eleanor_tess_ffi_postcard-s0001-2-3-cal-1098-0700_tess_v2_pc/hlsp_eleanor_tess_ffi_postcard-s0001-2-3_tess_v2_pm.txt ... [Done]
# Found TIC 117545157 (Gaia 6519854092991701632), with TESS magnitude 14.1348, RA 340.256255837183, and Dec -45.0066940425032
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-50-1b1617daa063> in <module>
#       2     star = eleanor.Source(tic = this_id , sector = 1)
#       3     print('Found TIC {0} (Gaia {1}), with TESS magnitude {2}, RA {3}, and Dec {4}'.format(star.tic, star.gaia, star.tess_mag, star.coords[0], star.coords[1]))
# ----> 4     data = eleanor.TargetData(star, height=15, width=15, bkg_size=31, do_psf=True, do_pca=True)
#       5     plt.figure(figsize = (15,5))
#       6
#
# ~/anaconda3/lib/python3.7/site-packages/eleanor/targetdata.py in __init__(self, source, height, width, save_postcard, do_pca, do_psf, bkg_size, crowded_field, cal_cadences, try_load, language)
#     167                 if source.tc == False:
#     168                     self.post_obj = Postcard(source.postcard, source.postcard_bkg,
# --> 169                                              source.postcard_path)
#     170                 else:
#     171                     self.post_obj = Postcard_tesscut(source.cutout)
#
# ~/anaconda3/lib/python3.7/site-packages/eleanor/postcard.py in __init__(self, filename, background, filepath)
#      56         self.filename = os.path.join(filepath, filename)
#      57         self.local_path = copy.copy(self.filename)
# ---> 58         self.hdu = fits.open(self.local_path)
#      59         self.background2d = fits.open(os.path.join(filepath, background))[1].data
#      60
#
# ~/anaconda3/lib/python3.7/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     156
#     157     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
# --> 158                             lazy_load_hdus, **kwargs)
#     159
#     160
#
# ~/anaconda3/lib/python3.7/site-packages/astropy/io/fits/hdu/hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     395         return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     396                              save_backup=save_backup, cache=cache,
# --> 397                              lazy_load_hdus=lazy_load_hdus, **kwargs)
#     398
#     399     @classmethod
#
# ~/anaconda3/lib/python3.7/site-packages/astropy/io/fits/hdu/hdulist.py in _readfrom(cls, fileobj, data, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#    1078                 hdulist._file.close()
#    1079
# -> 1080             raise OSError('Empty or corrupt FITS file')
#    1081
#    1082         if not lazy_load_hdus:
#
# OSError: Empty or corrupt FITS file

# %%
    data = eleanor.TargetData(star, height=15, width=15, bkg_size=31, do_psf=True, do_pca=True)
# Out:
# /Users/jshabazz/anaconda3/lib/python3.7/site-packages/astropy/wcs/wcs.py:682: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 58324.811816 from DATE-OBS.
# Set DATE-BEG to '2018-07-25T19:30:10.121' from MJD-BEG'.
#   FITSFixedWarning)
# /Users/jshabazz/anaconda3/lib/python3.7/site-packages/photutils/aperture/core.py:130: AstropyUserWarning: The "exact" method is not yet implemented for rectangular apertures -- using "subpixel" method with "subpixels=32"
#   'with "subpixels=32"', AstropyUserWarning)
# 100%|██████████| 1282/1282 [00:14<00:00, 89.34it/s]

# %%
    plt.figure(figsize = (15,5))

    q = data.quality == 0

    #plt.plot(data.time[q], data.raw_flux[q]/np.nanmedian(data.raw_flux[q])+0.06, 'k')
    #plt.plot(data.time[q], data.corr_flux[q]/np.nanmedian(data.corr_flux[q]) + 0.03, 'r')
    plt.plot(data.time[q], data.pca_flux[q]/np.nanmedian(data.pca_flux[q]), 'g')
    #plt.plot(data.time[q], data.psf_flux[q]/np.nanmedian(data.psf_flux[q]) - 0.02, 'b')
    plt.ylabel('Normalized Flux')
    plt.xlabel('Time [BJD - 2457000]')
    plt.title('WASP-100')
